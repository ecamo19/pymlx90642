# %% [raw]
# ---
# description: Fill in a module description here
# output-file: mlx90642.html
# title: mlx90642
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(MLX90642)
# Out:
# ---
#
# [source](https://github.com/ecamo19/pymlx90642/blob/main/pymlx90642/mlx90642.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### MLX90642
#
# >      MLX90642 (i2c_bus:int=1, i2c_addr:int=102)
#
# *Initialize MLX90642 sensor.*
